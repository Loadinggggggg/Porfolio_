# %%
! pip install git+https://github.com/PrithivirajDamodaran/Parrot.git
# Out:
# ...
#   Cloning https://github.com/PrithivirajDamodaran/Parrot.git to /tmp/pip-req-build-ffsbcmv1
#   Running command git clone -q https://github.com/PrithivirajDamodaran/Parrot.git /tmp/pip-req-build-ffsbcmv1
# ...
#      |████████████████████████████████| 4.2 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 41.3 MB/s
# ...
#      |████████████████████████████████| 50 kB 5.8 MB/s
# ...
#      |████████████████████████████████| 79 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 84 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 596 kB 36.3 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 27.8 MB/s
# ...
#   Created wheel for parrot: filename=parrot-1.0-py3-none-any.whl size=8695 sha256=8975a4a6cbfb1c58dc0dcddf0a6ade0fc3a3c5faed537cd7a0853210d42fda7d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lj8iykx5/wheels/d8/27/d8/b757755a5b0b804c59714fdd8a4e2733c20802f638f17f7d96
# ...

# %%
from parrot import Parrot
import torch
import warnings
warnings.filterwarnings("ignore")

# %%
def random_state(seed):
  torch.manual_seed(seed)
  if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

random_state(1234)

# %%
parrot = Parrot(model_tag="prithivida/parrot_paraphraser_on_T5", use_gpu=False)
# Out:
# Downloading:   0%|          | 0.00/1.84k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/908 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/476 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/736 [00:00<?, ?B/s]
# ...

# %%
phrases = ["The dream is to make a virtual reality that mimics the same reality feature and finally create a single-player VR where everyone can enjoy their definition of happiness. As an undergraduate, I studied a Bachelor of Science in philosophy, politics, and economics. I completed my studies with a dissertation on virtual reality. The conclusion of the analysis was two strong and definitive points: human beings are probably alone with themselves and perhaps inside a simulation. Secondly, it is impossible to reach peace within a society of different individuals. The separation of humanity with a single-player VR could be a definitive solution for the perpetuity of peace, which has a subjective meaning. Everyone should be able to create the world they wish. "]

# %%
for phrase in phrases:
  print("-"*100)
  print("Input_phrase: ", phrase)
  print("-"*100)
  para_phrases = parrot.augment(input_phrase=phrase)
  for para_phrase in para_phrases:
   print(para_phrase)
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  The dream is to make a virtual reality that mimics the same reality feature and finally create a single-player VR where everyone can enjoy their definition of happiness. As an undergraduate, I studied a Bachelor of Science in philosophy, politics, and economics. I completed my studies with a dissertation on virtual reality. The conclusion of the analysis was two strong and definitive points: human beings are probably alone with themselves and perhaps inside a simulation. Secondly, it is impossible to reach peace within a society of different individuals. The separation of humanity with a single-player VR could be a definitive solution for the perpetuity of peace, which has a subjective meaning. Everyone should be able to create the world they wish.
# ----------------------------------------------------------------------------------------------------
# ...

# %%
pip install pyspellchecker
# Out:
# ...
#      |████████████████████████████████| 2.7 MB 5.2 MB/s
# ...

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

# find those words that may be misspelled
misspelled = spell.unknown(['let', 'us', 'wlak','on','the','groun'])

for word in misspelled:
    # Get the one `most likely` answer
    print(spell.correction(word))

    # Get a list of `likely` options
    print(spell.candidates(word))
# Out:
# walk
# {'weak', 'blak', 'wlat', 'walk', 'alak', 'wak', 'flak'}

# %%
pip install language-tool-python

# %%
import language_tool_python

# %%
# importing the package
import language_tool_python

# using the tool
my_tool = language_tool_python.LanguageTool('en-US')

# given text
my_text = """LanguageTool provides utility to check grammar and spelling errors. We just have to paste the text here and click the 'Check Text' button. Click the colored phrases for for information on potential errors. or we can use this text too see an some of the issues that LanguageTool can dedect. Whot do someone thinks of grammar checkers? Please not that they are not perfect. Style problems get a blue marker: It is 7 P.M. in the evening. The weather was nice on Monday, 22 November 2021"""

# getting the matches
my_matches = my_tool.check(my_text)

# defining some variables
myMistakes = []
myCorrections = []
startPositions = []
endPositions = []

# using the for-loop
for rules in my_matches:
    if len(rules.replacements) > 0:
        startPositions.append(rules.offset)
        endPositions.append(rules.errorLength + rules.offset)
        myMistakes.append(my_text[rules.offset : rules.errorLength + rules.offset])
        myCorrections.append(rules.replacements[0])

# creating new object
my_NewText = list(my_text)

# rewriting the correct passage
for n in range(len(startPositions)):
    for i in range(len(my_text)):
        my_NewText[startPositions[n]] = myCorrections[n]
        if (i > startPositions[n] and i < endPositions[n]):
            my_NewText[i] = ""

my_NewText = "".join(my_NewText)

# printing the text
print(my_NewText)
# Out:
# ...
# Unzipping /tmp/tmpxtt3ynsr.zip to /root/.cache/language_tool_python.
# Downloaded https://www.languagetool.org/download/LanguageTool-5.7.zip to /root/.cache/language_tool_python.
# LanguageTool provides utility to check grammar and spelling errors. We just have to paste the text here and click the 'Check Text' button. Click the colored phrases for information on potential errors. Or we can use this text to see a some of the issues that LanguageTool can detect. Who do someone thinks of grammar checkers? Please note that they are not perfect. Style problems get a blue marker: It is 7 P.M.. The weather was nice on Monday, 22 November 2021

# %%
# importing the library
import language_tool_python

# creating the tool
my_tool = language_tool_python.LanguageTool('en-US')

# given text
my_text = 'I hopke you coknsider my application. I love AI.'

# correction
correct_text = my_tool.correct(my_text)

# printing some texts
print("Original Text:", my_text)
print("Text after correction:", correct_text)
# Out:
# Original Text: I hopke you coknsider my application. I love AI.
# Text after correction: I hope you consider my application. I love AI.
